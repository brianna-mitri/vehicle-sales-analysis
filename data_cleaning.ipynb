# %% [markdown]
# ## Setup

# %%
# imports
from kaggle.api.kaggle_api_extended import KaggleApi
import pandas as pd
import string
import re
import pycountry
import requests, time

# import access token
from api_key import access_token

# %% [markdown]
# #### Get sales df

# %%
# import dataset through kaggle api
api = KaggleApi()
api.authenticate()

api.dataset_download_files('kyanyoga/sample-sales-data', path='./Resources', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kyanyoga/sample-sales-data

# %%
# strip trailing spaces for columns with string dtype
def strip_trailing_spaces(df):

    # make copy
    main_df = df.copy()

    # loop through columns
    for col in main_df.columns:
        # if string column then strip
        if df[col].dtype == 'object':
            df[col] = main_df[col].str.strip()

    # return df
    return main_df

# %%
# convert to df
sales_df = pd.read_csv('Resources/sales_data_sample.csv', encoding='latin1')

# strip leading/trailing spaces
sales_df = strip_trailing_spaces(sales_df)

# display df
print(sales_df.shape)
sales_df.head()
# Out:
# (2823, 25)
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Data Check
# ---

# %% [markdown]
# ### Quick checks

# %%
# check nulls
sales_df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# look at unique count
sales_df.nunique()
# Out:
# ORDERNUMBER          307
# QUANTITYORDERED       58
# PRICEEACH           1016
# ORDERLINENUMBER       18
# SALES               2763
# ORDERDATE            252
# STATUS                 6
# QTR_ID                 4
# MONTH_ID              12
# YEAR_ID                3
# PRODUCTLINE            7
# MSRP                  80
# PRODUCTCODE          109
# CUSTOMERNAME          92
# PHONE                 91
# ADDRESSLINE1          92
# ADDRESSLINE2           9
# CITY                  73
# STATE                 16
# POSTALCODE            73
# COUNTRY               19
# TERRITORY              3
# CONTACTLASTNAME       77
# CONTACTFIRSTNAME      72
# DEALSIZE               3
# dtype: int64

# %%
# data types check
sales_df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
# ### Create datetime column

# %%
# convert orderdate
sales_df['ORDERDATE'] = pd.to_datetime(sales_df['ORDERDATE'])

# check dtypes
sales_df.dtypes
# Out:
# ORDERNUMBER                  int64
# QUANTITYORDERED              int64
# PRICEEACH                  float64
# ORDERLINENUMBER              int64
# SALES                      float64
# ORDERDATE           datetime64[ns]
# STATUS                      object
# QTR_ID                       int64
# MONTH_ID                     int64
# YEAR_ID                      int64
# PRODUCTLINE                 object
# MSRP                         int64
# PRODUCTCODE                 object
# CUSTOMERNAME                object
# PHONE                       object
# ADDRESSLINE1                object
# ADDRESSLINE2                object
# CITY                        object
# STATE                       object
# POSTALCODE                  object
# COUNTRY                     object
# TERRITORY                   object
# CONTACTLASTNAME             object
# CONTACTFIRSTNAME            object
# DEALSIZE                    object
# dtype: object

# %%
# order data by datetime
sales_df = sales_df.sort_values(by='ORDERDATE')

# %% [markdown]
# ## Fix Addresses
# ---

# %% [markdown]
# ### Check for duplicate naming issues (ex: "Company Inc." and "company inc")

# %%
# list of cols that could be duplicates (object type)
dupe_cols_check = list(sales_df.select_dtypes(include=['object']).columns)

# check for dupes
for col in dupe_cols_check:
    # create dupe col check
    col_check = f'{col}_CHECK'
    sales_df[col_check] = sales_df[col].str.title().str.translate(str.maketrans('', '', string.punctuation))

    # check if naming is already unique, if not use new col
    if sales_df[col_check].nunique() == sales_df[col].nunique():
        # drop new col
        sales_df = sales_df.drop(columns=[col_check]).copy()
        print(f'{col}: no duplicate naming issues')
    else:
        # drop old col
        sales_df = sales_df.drop(columns=[col]).copy()
        print(f'{col}: replaced column - found duplicate naming issues!!!')
# Out:
# STATUS: no duplicate naming issues
# PRODUCTLINE: no duplicate naming issues
# PRODUCTCODE: no duplicate naming issues
# CUSTOMERNAME: no duplicate naming issues
# PHONE: no duplicate naming issues
# ADDRESSLINE1: no duplicate naming issues
# ADDRESSLINE2: no duplicate naming issues
# CITY: no duplicate naming issues
# STATE: no duplicate naming issues
# POSTALCODE: no duplicate naming issues
# COUNTRY: no duplicate naming issues
# TERRITORY: no duplicate naming issues
# CONTACTLASTNAME: no duplicate naming issues
# CONTACTFIRSTNAME: no duplicate naming issues
# DEALSIZE: no duplicate naming issues

# %% [markdown]
# ### Check if full addresses are unique

# %%
# check if only one address option for each unique addressline
nunique_address = sales_df.groupby([
    'ADDRESSLINE1',
    'CITY',
    'COUNTRY'
]).nunique()

# loop through to see if any address has multiple of any of these fields
for col in ['ADDRESSLINE2', 'STATE', 'POSTALCODE', 'TERRITORY']:
    multiple_cnt = len(nunique_address[nunique_address[col] > 1])
    if multiple_cnt > 0:
        print(f'{col}: NOT unique -- multiples count of {multiple_cnt}')
    else:
        print(f'{col}: unique')
# Out:
# ADDRESSLINE2: unique
# STATE: unique
# POSTALCODE: unique
# TERRITORY: unique

# %% [markdown]
# ### Create customer ID

# %%
# groupby customer name
sales_df['CUSTOMER_ID'] = sales_df.groupby([
    'CUSTOMERNAME',
    'CONTACTLASTNAME', 
    'CONTACTFIRSTNAME',
    # 'ADDRESSLINE1',
    # 'ADDRESSLINE2',
    # 'CITY',
    # 'STATE',
    # 'POSTALCODE',
    # 'COUNTRY',
    # 'TERRITORY'
]).ngroup() + 1

sales_df.head()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 1267        10100               22      86.51                4  1903.22
# 2024        10100               49      34.47                1  1689.03
# 1539        10101               45      31.20                3  1404.00
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 578  2003-01-06  Shipped       1         1     2003  ...          NaN
# 680  2003-01-06  Shipped       1         1     2003  ...          NaN
# 1267 2003-01-06  Shipped       1         1     2003  ...          NaN
# 2024 2003-01-06  Shipped       1         1     2003  ...          NaN
# 1539 2003-01-09  Shipped       1         1     2003  ...          NaN
#
#            CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# 578      Nashua    NH      62005      USA       NaN           Young
# 680      Nashua    NH      62005      USA       NaN           Young
# 1267     Nashua    NH      62005      USA       NaN           Young
# 2024     Nashua    NH      62005      USA       NaN           Young
# 1539  Frankfurt   NaN      60528  Germany      EMEA          Keitel
#
#      CONTACTFIRSTNAME DEALSIZE CUSTOMER_ID
# 578           Valarie   Medium          61
# 680           Valarie   Medium          61
# 1267          Valarie    Small          61
# 2024          Valarie    Small          61
# 1539           Roland    Small          14
#
# [5 rows x 26 columns]

# %%
# check count of unique customers
print(sales_df.CUSTOMERNAME.nunique())
print(sales_df.CUSTOMER_ID.nunique())
# Out:
# 92
# 92

# %% [markdown]
# ### Get addresses (one address associated with one customer)

# %%
# function to pick a non null value from each col --> just in case
def pick_first_notna(col):
    # drop nulls
    not_na = col.dropna()

    # return first non null value if present
    return not_na.iloc[0] if len(not_na) > 0 else None

# %%
# group addresses by customer id and get values for as many columns
address_df = sales_df.groupby('CUSTOMER_ID', as_index=False).agg({
    'ADDRESSLINE1': pick_first_notna,
    'ADDRESSLINE2': pick_first_notna,
    'CITY': pick_first_notna,
    'STATE': pick_first_notna,
    'POSTALCODE': pick_first_notna,
    'COUNTRY': pick_first_notna,
    'TERRITORY': pick_first_notna
})

# %%
# display length and nulls
print(f'Number of rows: {len(address_df)}')
address_df.isna().sum()
# Out:
# Number of rows: 92
# CUSTOMER_ID      0
# ADDRESSLINE1     0
# ADDRESSLINE2    83
# CITY             0
# STATE           46
# POSTALCODE       3
# COUNTRY          0
# TERRITORY       38
# dtype: int64

# %% [markdown]
# ### Drop territory column

# %%
# look into territories
print(f'Nulls: {address_df.TERRITORY.isna().sum()}')
address_df.TERRITORY.value_counts()
# Out:
# Nulls: 38
# TERRITORY
# EMEA     44
# APAC      6
# Japan     4
# Name: count, dtype: int64

# %%
# drop
address_df = address_df.drop(columns=['TERRITORY']).copy()
address_df.head(3)
# Out:
#    CUSTOMER_ID           ADDRESSLINE1 ADDRESSLINE2        CITY STATE  \
# 0            1      Fauntleroy Circus         None  Manchester  None
# 1            2  1 rue Alsace-Lorraine         None    Toulouse  None
# 2            3    Via Monte Bianco 34         None      Torino  None
#
#   POSTALCODE COUNTRY
# 0    EC2 5NT      UK
# 1      31000  France
# 2      10100   Italy

# %% [markdown]
# ### Build single address column

# %%
# # function to build a single address string/col
# def build_full_address(row):
#     parts = []
    
#     for col in ['ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY']:
#         if pd.notnull(row[col]):
#             parts.append(row[col])
#     return ', '.join(parts)

# %%
# # create single address column
# address_df['FULL_ADDRESS'] = address_df.apply(build_full_address, axis=1)
# address_df.head()

# %% [markdown]
# ### Get country codes

# %%
# update abbreviated countries
address_df['COUNTRY'] = address_df['COUNTRY'].replace({
    'UK': 'United Kingdom',
    'USA': 'United States'
})
address_df.COUNTRY.unique()
# Out:
# array(['United Kingdom', 'France', 'Italy', 'Australia', 'United States',
#        'Norway', 'Germany', 'Spain', 'Canada', 'Ireland', 'Philippines',
#        'Denmark', 'Singapore', 'Austria', 'Japan', 'Finland', 'Belgium',
#        'Sweden', 'Switzerland'], dtype=object)

# %%
# get three character country code
countries = address_df.COUNTRY.unique()

country_code_dict = {
    country: pycountry.countries.get(name=country).alpha_3
    for country in countries
}

address_df['COUNTRY_CODE'] = address_df['COUNTRY'].map(country_code_dict)

# display
address_df.head(3)
# Out:
#    CUSTOMER_ID           ADDRESSLINE1 ADDRESSLINE2        CITY STATE  \
# 0            1      Fauntleroy Circus         None  Manchester  None
# 1            2  1 rue Alsace-Lorraine         None    Toulouse  None
# 2            3    Via Monte Bianco 34         None      Torino  None
#
#   POSTALCODE         COUNTRY COUNTRY_CODE
# 0    EC2 5NT  United Kingdom          GBR
# 1      31000          France          FRA
# 2      10100           Italy          ITA

# %%
# double check codes
country_code_dict
# Out:
# {'United Kingdom': 'GBR',
#  'France': 'FRA',
#  'Italy': 'ITA',
#  'Australia': 'AUS',
#  'United States': 'USA',
#  'Norway': 'NOR',
#  'Germany': 'DEU',
#  'Spain': 'ESP',
#  'Canada': 'CAN',
#  'Ireland': 'IRL',
#  'Philippines': 'PHL',
#  'Denmark': 'DNK',
#  'Singapore': 'SGP',
#  'Austria': 'AUT',
#  'Japan': 'JPN',
#  'Finland': 'FIN',
#  'Belgium': 'BEL',
#  'Sweden': 'SWE',
#  'Switzerland': 'CHE'}

# %% [markdown]
# ### Validate addresses with ArcGIS geocoding service api

# %%
address_df.isna().sum()
# Out:
# CUSTOMER_ID      0
# ADDRESSLINE1     0
# ADDRESSLINE2    83
# CITY             0
# STATE           46
# POSTALCODE       3
# COUNTRY          0
# COUNTRY_CODE     0
# dtype: int64

# %%
# ArcGIS REST API geocoding service url
api_url = 'https://geocode-api.arcgis.com/arcgis/rest/services/World/GeocodeServer/findAddressCandidates'

# %%
# test df
two_addresses = address_df.head(2).copy()
two_addresses
# Out:
#    CUSTOMER_ID           ADDRESSLINE1 ADDRESSLINE2        CITY STATE  \
# 0            1      Fauntleroy Circus         None  Manchester  None
# 1            2  1 rue Alsace-Lorraine         None    Toulouse  None
#
#   POSTALCODE         COUNTRY COUNTRY_CODE
# 0    EC2 5NT  United Kingdom          GBR
# 1      31000          France          FRA

# %%
# output fields
out_fields = ','.join([
    'StAddr',
    'SubAddr',
    'City',
    'Region',
    'RegionAbbr',
    'Subregion',
    'Postal',
    #'Country',
    'CntryName',
    'CountryCode',
    'Addr_type', 'Match_addr', 'Status'  #quality/diagnostics
])

# %%
# function to return '' for None address fields
def none_to_empty(field):
    return '' if field is None else field

# function to get params
def build_params(row):

    # setup mulitfield query (return nothing for null fields)
    query = {
        'address': none_to_empty(row.ADDRESSLINE1),
        'address2': none_to_empty(row.ADDRESSLINE2),
        'city': none_to_empty(row.CITY),
        'region': none_to_empty(row.STATE),
        'postal': none_to_empty(row.POSTALCODE),
        'countryCode': none_to_empty(row.COUNTRY_CODE)
    }

    # drop blanks from query 
    query = {field: input for field, input in query.items() if input}

    base = {
        'f': 'pjson',
        'token': access_token,
        'forStorage': 'false',
        'langCode': 'ENG',
        'outFields': out_fields
    }

    base.update(query)

    # return parameters
    return base

# %%
# get official/valid addresses
val_addresses = []

for _, row in address_df.iterrows():
    
    # get params
    params_dict = build_params(row)
    
    try:
        # make api request
        address_data = requests.get(api_url, params=params_dict, timeout=10).json()
        print(address_data)
        
        candidate = address_data.get('candidates', [None])[0]
        time.sleep(15)

        # build dict
        if candidate:
            attr = candidate['attributes']
            val_addresses.append({
                'CUSTOMER_ID'     : row.CUSTOMER_ID,
                'STD_ADDRESSLINE1': attr['StAddr']      or pd.NA,
                'STD_ADDRESSLINE2': attr['SubAddr']     or pd.NA,
                'STD_CITY'        : attr['City']        or pd.NA,
                'STD_REGION'      : attr['Region']      or pd.NA,
                'STD_REGIONCODE'  : attr['RegionAbbr']  or pd.NA,
                'STD_POSTALCODE'  : attr['Postal']      or pd.NA,
                'STD_COUNTRY'     : attr['CntryName']   or pd.NA,
                'STD_COUNTRY_CODE': attr['CountryCode'] or pd.NA,
                'ADDR_TYPE'       : attr['Addr_type']   or pd.NA,
                'MATCH_ADDR'      : attr['Match_addr']  or pd.NA,
                'STATUS'          : attr['Status']      or pd.NA,
                'SCORE'           : candidate['score']  or pd.NA
            })
    
    # display errors
    except requests.RequestException as e:
        print(f'Error for {row.CUSTOMER_ID}: {e}')
        print(f'Error type: {type(e)}')
        print(f'Arguments: {e.args}')
    except Exception as e:
        print(f'Unexpected error for {row.CUSTOMER_ID}: {e}')
        print(f'Error type: {type(e)}')
        print(f'Arguments: {e.args}')
# Out:
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Manchester, Greater Manchester, England', 'location': {'x': -2.245275942, 'y': 53.47895622}, 'score': 71.5, 'attributes': {'Status': 'T', 'Match_addr': 'Manchester, Greater Manchester, England', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Manchester', 'Subregion': 'Greater Manchester', 'Region': 'England', 'RegionAbbr': '', 'Postal': '', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.318275942, 'ymin': 53.40595622, 'xmax': -2.172275942, 'ymax': 53.55195622}}, {'address': 'Manchester, Lancashire, England', 'location': {'x': -2.2343765, 'y': 53.4807125}, 'score': 71.5, 'attributes': {'Status': 'T', 'Match_addr': 'Manchester, Lancashire, England', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Manchester', 'Subregion': 'Lancashire', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': '', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.4193765, 'ymin': 53.2957125, 'xmax': -2.0493765, 'ymax': 53.6657125}}, {'address': 'Manchester, England', 'location': {'x': -2.23743, 'y': 53.48095}, 'score': 71.5, 'attributes': {'Status': 'T', 'Match_addr': 'Manchester, England', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Manchester', 'Subregion': 'Manchester', 'Region': 'England', 'RegionAbbr': '', 'Postal': '', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.32243, 'ymin': 53.39595, 'xmax': -2.15243, 'ymax': 53.56595}}, {'address': 'Manchester, Lancashire, England', 'location': {'x': -2.233106143544, 'y': 53.452988146468}, 'score': 71.4, 'attributes': {'Status': 'T', 'Match_addr': 'Manchester, Lancashire, England', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 
 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': 'Via Monte Bianco 34', 'City': 'Leini', 'Subregion': 'Torino', 'Region': 'Piemonte', 'RegionAbbr': '', 'Postal': '10040', 'CntryName': 'Italia', 'CountryCode': 'ITA'}, 'extent': {'xmin': 7.73751046699, 'ymin': 45.150359799854, 'xmax': 7.73951046699, 'ymax': 45.152359799854}}, {'address': 'Via Monte Bianco 34, 10024, Moncalieri, Torino', 'location': {'x': 7.666774367758, 'y': 45.014927980963}, 'score': 92.59, 'attributes': {'Status': 'T', 'Match_addr': 'Via Monte Bianco 34, 10024, Moncalieri, Torino', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': 'Via Monte Bianco 34', 'City': 'Moncalieri', 'Subregion': 'Torino', 'Region': 'Piemonte', 'RegionAbbr': '', 'Postal': '10024', 'CntryName': 'Italia', 'CountryCode': 'ITA'}, 'extent': {'xmin': 7.665774367758, 'ymin': 45.013927980963, 'xmax': 7.667774367758, 'ymax': 45.015927980963}}, {'address': 'Via Monte Bianco 34, 10099, San Mauro Torinese, Torino', 'location': {'x': 7.754827796958, 'y': 45.093323757333}, 'score': 92.59, 'attributes': {'Status': 'M', 'Match_addr': 'Via Monte Bianco 34, 10099, San Mauro Torinese, Torino', 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': 'Via Monte Bianco 34', 'City': 'San Mauro Torinese', 'Subregion': 'Torino', 'Region': 'Piemonte', 'RegionAbbr': '', 'Postal': '10099', 'CntryName': 'Italia', 'CountryCode': 'ITA'}, 'extent': {'xmin': 7.753827796958, 'ymin': 45.092323757333, 'xmax': 7.755827796958, 'ymax': 45.094323757333}}, {'address': 'Via Sebastiano Bianco 34, 10080, San Benigno Canavese, Torino', 'location': {'x': 7.789810005313, 'y': 45.224697264289}, 'score': 89.83, 'attributes': {'Status': 'M', 'Match_addr': 'Via Sebastiano Bianco 34, 10080, San Benigno Canavese, Torino', 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': 'Via Sebastiano Bianco 34', 'City': 'San Benigno Canavese', 'Subregion': 'Torino', 'Region': 'Piemonte', 'RegionAbbr': '', 'Postal': '10080', 'CntryName': 'Italia', 'CountryCode': 'ITA'}, 'extent': {'xmin': 7.788810005313, 'ymin': 45.223697264289, 'xmax': 7.790810005313, 'ymax': 45.225697264289}}, {'address': "Strada della Ca' Bianca 34, 10023, Chieri, Torino", 'location': {'x': 7.83960883027, 'y': 44.961468749271}, 'score': 84.84, 'attributes': {'Status': 'M', 'Match_addr': "Strada della Ca' Bianca 34, 10023, Chieri, Torino", 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': "Strada della Ca' Bianca 34", 'City': 'Chieri', 'Subregion': 'Torino', 'Region': 'Piemonte', 'RegionAbbr': '', 'Postal': '10023', 'CntryName': 'Italia', 'CountryCode': 'ITA'}, 'extent': {'xmin': 7.83860883027, 'ymin': 44.96 ...
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '201 Miller St, L 15, North Sydney, Sydney, New South Wales, 2060', 'location': {'x': 151.207765793059, 'y': -33.836398578173}, 'score': 100, 'attributes': {'Status': 'M', 'Match_addr': '201 Miller St, L 15, North Sydney, Sydney, New South Wales, 2060', 'Addr_type': 'Subaddress', 'SubAddr': 'L 15', 'StAddr': '201 Miller St', 'City': 'Sydney', 'Subregion': '', 'Region': 'New South Wales', 'RegionAbbr': 'NSW', 'Postal': '2060', 'CntryName': 'Australia', 'CountryCode': 'AUS'}, 'extent': {'xmin': 151.206765793059, 'ymin': -33.837398578173, 'xmax': 151.208765793059, 'ymax': -33.835398578173}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '54 Place Royale, 44000, Nantes, Loire-Atlantique, Pays de la Loire', 'location': {'x': -1.557999136263, 'y': 47.214324753963}, 'score': 96.3, 'attributes': {'Status': 'M', 'Match_addr': '54 Place Royale, 44000, Nantes, Loire-Atlantique, Pays de la Loire', 'Addr_type': 'StreetAddressExt', 'SubAddr': '', 'StAddr': '54 Place Royale', 'City': 'Nantes', 'Subregion': 'Loire-Atlantique', 'Region': 'Pays de la Loire', 'RegionAbbr': 'PDL', 'Postal': '44000', 'CntryName': 'France', 'CountryCode': 'FRA'}, 'extent': {'xmin': -1.558999136263, 'ymin': 47.213324753963, 'xmax': -1.556999136263, 'ymax': 47.215324753963}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '7 Allen St, Glen Waverley, Melbourne, Victoria, 3150', 'location': {'x': 145.161902385374, 'y': -37.887649237126}, 'score': 98.51, 'attributes': {'Status': 'M', 'Match_addr': '7 Allen St, Glen Waverley, Melbourne, Victoria, 3150', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '7 Allen St', 'City': 'Melbourne', 'Subregion': '', 'Region': 'Victoria', 'RegionAbbr': 'VIC', 'Postal': '3150', 'CntryName': 'Australia', 'CountryCode': 'AUS'}, 'extent': {'xmin': 145.160902385374, 'ymin': -37.888649237126, 'xmax': 145.162902385374, 'ymax': -37.886649237126}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'location': {'x': 144.981859021346, 'y': -37.854866985164}, 'score': 100, 'attributes': {'Status': 'T', 'Match_addr': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'Addr_type': 'Subaddress', 'SubAddr': 'L 3', 'StAddr': '636 St Kilda Rd', 'City': 'Melbourne', 'Subregion': '', 'Region': 'Victoria', 'RegionAbbr': 'VIC', 'Postal': '3004', 'CntryName': 'Australia', 'CountryCode': 'AUS'}, 'extent': {'xmin': 144.980859021346, 'ymin': -37.855866985164, 'xmax': 144.982859021346, 'ymax': -37.853866985164}}, {'address': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'location': {'x': 144.981859021346, 'y': -37.854866985164}, 'score': 100, 'attributes': {'Status': 'T', 'Match_addr': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'Addr_type': 'Subaddress', 'SubAddr': 'L 3', 'StAddr': '636 St Kilda Rd', 'City': 'Melbourne', 'Subregion': '', 'Region': 'Victoria', 'RegionAbbr': 'VIC', 'Postal': '3004', 'CntryName': 'Australia', 'CountryCode': 'AUS'}, 'extent': {'xmin': 144.980859021346, 'ymin': -37.855866985164, 'xmax': 144.982859021346, 'ymax': -37.853866985164}}, {'address': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'location': {'x': 144.981859021346, 'y': -37.854866985164}, 'score': 100, 'attributes': {'Status': 'T', 'Match_addr': '636 St Kilda Rd, L 3, Melbourne, Victoria, 3004', 'Addr_type': 'Subaddress', 'SubAddr': 'L 3', 'StAddr':
}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Lyoner Straße 34, 60528, Frankfurt am Main, Schwanheim, Hessen', 'location': {'x': 8.623652853362, 'y': 50.078945518508}, 'score': 100, 'attributes': {'Status': 'M', 'Match_addr': 'Lyoner Straße 34, 60528, Frankfurt am Main, Schwanheim, Hessen', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': 'Lyoner Straße 34', 'City': 'Frankfurt am Main', 'Subregion': 'Frankfurt am Main', 'Region': 'Hessen', 'RegionAbbr': 'HE', 'Postal': '60528', 'CntryName': 'Deutschland', 'CountryCode': 'DEU'}, 'extent': {'xmin': 8.622652853362, 'ymin': 50.077945518508, 'xmax': 8.624652853362, 'ymax': 50.079945518508}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '92561, Mountain Center, California', 'location': {'x': -116.578924, 'y': 33.580712}, 'score': 77, 'attributes': {'Status': 'M', 'Match_addr': '92561, Mountain Center, California', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Mountain Center', 'Subregion': 'Riverside County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '92561', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -116.779924, 'ymin': 33.379712, 'xmax': -116.377924, 'ymax': 33.781712}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '28023, Madrid, Community of Madrid', 'location': {'x': -3.7808871, 'y': 40.47218}, 'score': 77, 'attributes': {'Status': 'M', 'Match_addr': '28023, Madrid, Community of Madrid', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Madrid', 'Subregion': 'Madrid', 'Region': 'Community of Madrid', 'RegionAbbr': 'MD', 'Postal': '28023', 'CntryName': 'Spain', 'CountryCode': 'ESP'}, 'extent': {'xmin': -3.8148871, 'ymin': 40.43818, 'xmax': -3.7468871, 'ymax': 40.50618}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Cambridge, Massachusetts', 'location': {'x': -71.105015, 'y': 42.365248}, 'score': 76.3, 'attributes': {'Status': 'T', 'Match_addr': 'Cambridge, Massachusetts', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Cambridge', 'Subregion': 'Middlesex County', 'Region': 'Massachusetts', 'RegionAbbr': 'MA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -71.142015, 'ymin': 42.328248, 'xmax': -71.068015, 'ymax': 42.402248}}, {'address': 'Cambridge, Massachusetts', 'location': {'x': -71.10561, 'y': 42.3751}, 'score': 76.3, 'attributes': {'Status': 'T', 'Match_addr': 'Cambridge, Massachusetts', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Cambridge', 'Subregion': 'Middlesex County', 'Region': 'Massachusetts', 'RegionAbbr': 'MA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -71.14361, 'ymin': 42.3371, 'xmax': -71.06761, 'ymax': 42.4131}}, {'address': 'Cambridge, Massachusetts', 'location': {'x': -71.812016, 'y': 42.244538}, 'score': 76.3, 'attributes': {'Status': 'T', 'Match_addr': 'Cambridge, Massachusetts', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Cambridge', 'Subregion': 'Worcester County', 'Region': 'Massachusetts', 'RegionAbbr': 'MA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -71.819016, 'ymin': 42.237538, 'xmax': -71.805016, 'ymax': 42.251538}}, {'address': 'Cambridge, Massachusetts', 'location': {'x': -71.20922, 'y': 42.33704}, 'score': 76.3, 'attributes': {'Status': 'T', 'Match_addr': 'Cambridge, Massachusetts', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Newton', 'Subregion': 'Middlesex County', 'Region': 'Massachusetts', 'RegionAbbr': 'MA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin':
 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -75.259617901649, 'ymin': 40.092691980421, 'xmax': -75.257617901649, 'ymax': 40.094691980421}}, {'address': '1st St, Port Carbon, Pennsylvania, 17965', 'location': {'x': -76.164937176957, 'y': 40.698742611971}, 'score': 88.88, 'attributes': {'Status': 'T', 'Match_addr': '1st St, Port Carbon, Pennsylvania, 17965', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': '1st St', 'City': 'Port Carbon', 'Subregion': 'Schuylkill County', 'Region': 'Pennsylvania', 'RegionAbbr': 'PA', 'Postal': '17965', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -76.165937176957, 'ymin': 40.697742611971, 'xmax': -76.163937176957, 'ymax': 40.699742611971}}, {'address': '782 N Hirst St, Philadelphia, Pennsylvania, 19139', 'location': {'x': -75.244475823895, 'y': 39.966431091627}, 'score': 86.19, 'attributes': {'Status': 'M', 'Match_addr': '782 N Hirst St, Philadelphia, Pennsylvania, 19139', 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': '782 N Hirst St', 'City': 'Philadelphia', 'Subregion': 'Philadelphia County', 'Region': 'Pennsylvania', 'RegionAbbr': 'PA', 'Postal': '19139', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -75.245475823895, 'ymin': 39.965431091627, 'xmax': -75.243475823895, 'ymax': 39.967431091627}}, {'address': 'N Hirst St, Philadelphia, Pennsylvania, 19151', 'location': {'x': -75.24372898752, 'y': 39.973137008479}, 'score': 80.12, 'attributes': {'Status': 'T', 'Match_addr': 'N Hirst St, Philadelphia, Pennsylvania, 19151', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'N Hirst St', 'City': 'Philadelphia', 'Subregion': 'Philadelphia County', 'Region': 'Pennsylvania', 'RegionAbbr': 'PA', 'Postal': '19151', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -75.24472898752, 'ymin': 39.972137008479, 'xmax': -75.24272898752, 'ymax': 39.974137008479}}, {'address': 'S Hirst St, Philadelphia, Pennsylvania, 19139', 'location': {'x': -75.246472510158, 'y': 39.957756006605}, 'score': 80.12, 'attributes': {'Status': 'T', 'Match_addr': 'S Hirst St, Philadelphia, Pennsylvania, 19139', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'S Hirst St', 'City': 'Philadelphia', 'Subregion': 'Philadelphia County', 'Region': 'Pennsylvania', 'RegionAbbr': 'PA', 'Postal': '19139', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -75.247472510158, 'ymin': 39.956756006605, 'xmax': -75.245472510158, 'ymax': 39.958756006605}}, {'address': 'N Hirst St, Philadelphia, Pennsylvania, 19139', 'location': {'x': -75.244561179026, 'y': 39.965616107006}, 'score': 80.12, 'attributes': {'Status': 'T', 'Match_addr': 'N Hirst St, Philadelphia, Pennsylvania, 19139', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'N Hirst St', 'City': 'Philadelphia', 'Subregion': 'Philadelphia County', 'Region': 'Pennsylvania', 'RegionAbbr': 'PA', 'Postal': '19139', 'CntryName': 'Unit ...
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '10022, New York, New York', 'location': {'x': -73.968514, 'y': 40.758892}, 'score': 84, 'attributes': {'Status': 'M', 'Match_addr': '10022, New York, New York', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'New York', 'Subregion': 'New York County', 'Region': 'New York', 'RegionAbbr': 'NY', 'Postal': '10022', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -73.976514, 'ymin': 40.750892, 'xmax': -73.960514, 'ymax': 40.766892}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address':
 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'City of San Francisco', 'Subregion': 'San Francisco County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -122.7395, 'ymin': 37.48123, 'xmax': -122.1455, 'ymax': 38.07523}}, {'address': 'San Francisco County, California', 'location': {'x': -122.427853533333, 'y': 37.926273333333}, 'score': 81.43, 'attributes': {'Status': 'T', 'Match_addr': 'San Francisco County, California', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': '', 'Subregion': 'San Francisco County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -122.722853533333, 'ymin': 37.631273333333, 'xmax': -122.132853533333, 'ymax': 38.221273333333}}, {'address': 'San Francisco County, California', 'location': {'x': -122.4425, 'y': 37.77823}, 'score': 81.43, 'attributes': {'Status': 'T', 'Match_addr': 'San Francisco County, California', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': '', 'Subregion': 'San Francisco County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -124.6975, 'ymin': 35.52323, 'xmax': -120.1875, 'ymax': 40.03323}}, {'address': 'San Francisco, Minnesota', 'location': {'x': -93.694662, 'y': 44.692118}, 'score': 78.46, 'attributes': {'Status': 'T', 'Match_addr': 'San Francisco, Minnesota', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'San Francisco', 'Subregion': 'Carver County', 'Region': 'Minnesota', 'RegionAbbr': 'MN', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -93.756662, 'ymin': 44.630118, 'xmax': -93.632662, 'ymax': 44.754118}}, {'address': 'San Francisco, New Mexico', 'location': {'x': -106.839193, 'y': 34.395898}, 'score': 78.46, 'attributes': {'Status': 'T', 'Match_addr': 'San Francisco, New Mexico', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'San Francisco', 'Subregion': 'Socorro County', 'Region': 'New Mexico', 'RegionAbbr': 'NM', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -106.846193, 'ymin': 34.388898, 'xmax': -106.832193, 'ymax': 34.402898}}, {'address': 'San Francisco, Middle Frisco, New Mexico', 'location': {'x': -108.76617, 'y': 33.69339}, 'score': 78.46, 'attributes': {'Status': 'T', 'Match_addr': 'San Francisco, Middle Frisco, New Mexico', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '', 'City': 'Middle Frisco', 'Subregion': 'Catron County', 'Region': 'New Mexico', 'RegionAbbr': 'NM', 'Postal': '', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent ...
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Calle de Araquil 67, 28023, Aravaca, Madrid, Comunidad de Madrid', 'location': {'x': -3.779911220998, 'y': 40.460445788701}, 'score': 98.9, 'attributes': {'Status': 'M', 'Match_addr': 'Calle de Araquil 67, 28023, Aravaca, Madrid, Comunidad de Madrid', 'Addr_type': 'StreetAddressExt', 'SubAddr': '', 'StAddr': 'Calle de Araquil 67', 'City': 'Madrid', 'Subregion': 'Madrid', 'Region': 'Comunidad de Madrid', 'RegionAbbr': 'MD', 'Postal': '28023', 'CntryName': 'España', 'CountryCode': 'ESP'}, 'extent': {'xmin': -3.780911220998, 'ymin': 40.459445788701, 'xmax': -3.778911220998, 'ymax': 40.461445788701}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '1227, Makati City, National Capital Region', 'location': {'x': 121.0240654, 'y': 14.5595136}, 'score': 77, 'attributes': {'Status': 'M', 'Match_addr': '1227, Makati City, National Capital Region', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Makati City', 'Subregion': 'Metro Manila', 'Region': 'National Capital Region', 'RegionAbbr': '', 'Postal': '1227', 'CntryName': 'Philippines', 'CountryCode': 'PHL'}, 'extent': {'xmin': 121.0230654, 'ymin': 14.5585136, 'xmax': 121.0250654, 'ymax': 14.5605136}}]}
# ...
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '2-2-8, Roppongi, Minato-Ku, Tokyo, 1060032', 'location': {'x': 139.738734420267, 'y': 35.667260831998}, 'score': 100, 'attributes': {'Status': 'M', 'Match_addr': '2-2-8, Roppongi, Minato-Ku, Tokyo, 1060032', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '2-2-8', 'City': '', 'Subregion': '', 'Region': 'Tokyo', 'RegionAbbr': '', 'Postal': '1060032', 'CntryName': 'Japan', 'CountryCode': 'JPN'}, 'extent': {'xmin': 139.737734420267, 'ymin': 35.666260831998, 'xmax': 139.739734420267, 'ymax': 35.668260831998}}, {'address': '2-2, Roppongi, Minato-Ku, Tokyo, 1060032', 'location': {'x': 139.738998869312, 'y': 35.667463003503}, 'score': 98.74, 'attributes': {'Status': 'M', 'Match_addr': '2-2, Roppongi, Minato-Ku, Tokyo, 1060032', 'Addr_type': 'Locality', 'SubAddr': '', 'StAddr': '2-2', 'City': '', 'Subregion': '', 'Region': 'Tokyo', 'RegionAbbr': '', 'Postal': '1060032', 'CntryName': 'Japan', 'CountryCode': 'JPN'}, 'extent': {'xmin': 139.737998869312, 'ymin': 35.666463003503, 'xmax': 139.739998869312, 'ymax': 35.668463003503}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Merheimer Straße 369, 50739, Köln, Mauenheim, Nordrhein-Westfalen', 'location': {'x': 6.946159017713, 'y': 50.973436995863}, 'score': 97.52, 'attributes': {'Status': 'M', 'Match_addr': 'Merheimer Straße 369, 50739, Köln, Mauenheim, Nordrhein-Westfalen', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': 'Merheimer Straße 369', 'City': 'Köln', 'Subregion': 'Köln', 'Region': 'Nordrhein-Westfalen', 'RegionAbbr': 'NW', 'Postal': '50739', 'CntryName': 'Deutschland', 'CountryCode': 'DEU'}, 'extent': {'xmin': 6.945159017713, 'ymin': 50.972436995863, 'xmax': 6.947159017713, 'ymax': 50.974436995863}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Keskuskatu 45, 00100, Helsinki', 'location': {'x': 24.942860587961, 'y': 60.170145119167}, 'score': 96.9, 'attributes': {'Status': 'M', 'Match_addr': 'Keskuskatu 45, 00100, Helsinki', 'Addr_type': 'StreetAddressExt', 'SubAddr': '', 'StAddr': 'Keskuskatu 45', 'City': 'Helsinki', 'Subregion': 'Uusimaa', 'Region': '', 'RegionAbbr': '', 'Postal': '00100', 'CntryName': 'Suomi', 'CountryCode': 'FIN'}, 'extent': {'xmin': 24.941860587961, 'ymin': 60.169145119167, 'xmax': 24.943860587961, 'ymax': 60.171145119167}}, {'address': 'Keskuskatu, 00130, Helsinki', 'location': {'x': 24.943020075836, 'y': 60.167759284036}, 'score': 90.2, 'attributes': {'Status': 'M', 'Match_addr': 'Keskuskatu, 00130, Helsinki', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'Keskuskatu', 'City': 'Helsinki', 'Subregion': 'Uusimaa', 'Region': '', 'RegionAbbr': '', 'Postal': '00130', 'CntryName': 'Suomi', 'CountryCode': 'FIN'}, 'extent': {'xmin': 24.942020075836, 'ymin': 60.166759284036, 'xmax': 24.944020075836, 'ymax': 60.168759284036}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'Hillside Rd, South Pasadena, California, 91030', 'location': {'x': -118.159198050009, 'y': 34.122906574093}, 'score': 79.2, 'attributes': {'Status': 'M', 'Match_addr': 'Hillside Rd, South Pasadena, California, 91030', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'Hillside Rd', 'City': 'South Pasadena', 'Subregion': 'Los Angeles County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '91030', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -118.160198050009, 'ymin': 34.121906574093, 'xmax': -118.158198050009, 'ymax': 34.123906574093}}, {'address': 'Hillside Ter, Pasadena, California, 91105', 'location': {'x': -118.167983922765, 'y': 34.131815093948}, 'score': 77.61, 'attributes': {'Status': 'T', 'Match_addr': 'Hillside Ter, Pasadena, California, 91105', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'Hillside Ter', 'City': 'Pasadena', 'Subregion': 'Los Angeles County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '91105', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -118.168983922765, 'ymin': 34.130815093948, 'xmax': -118.166983922765, 'ymax': 34.132815093948}}, {'address': 'Hillside Rd, Pasadena, California, 91105', 'location': {'x': -118.159632950447, 'y': 34.124815534803}, 'score': 77.61, 'attributes': {'Status': 'T', 'Match_addr': 'Hillside Rd, Pasadena, California, 91105', 'Addr_type': 'StreetName', 'SubAddr': '', 'StAddr': 'Hillside Rd', 'City': 'Pasadena', 'Subregion': 'Los Angeles County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '91105', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -118.160632950447, 'ymin': 34.123815534803, 'xmax': -118.158632950447, 'ymax': 34.125815534803}}, {'address': '90003, Los Angeles, California', 'location': {'x': -118.2738936, 'y': 33.9629121}, 'score': 77, 'attributes': {'Status': 'M', 'Match_addr': '90003, Los Angeles, California', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Los Angeles', 'Subregion': 'Los Angeles County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '90003', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -118.2918936, 'ymin': 33.9449121, 'xmax': -118.2558936, 'ymax': 33.9809121}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '12 Barkeley Drive, Seaforth, Liverpool, Merseyside, England, L21 4LX', 'location': {'x': -3.014800922486, 'y': 53.463463682431}, 'score': 80.14, 'attributes': {'Status': 'M', 'Match_addr': '12 Barkeley Drive, Seaforth, Liverpool, Merseyside, England, L21 4LX', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '12 Barkeley Drive', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L21 4LX', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -3.015800922486, 'ymin': 53.462463682431, 'xmax': -3.013800922486, 'ymax': 53.464463682431}}, {'address': '12 Berkley Avenue, West Derby, Liverpool, Merseyside, England, L12 4YS', 'location': {'x': -2.888222030778, 'y': 53.437972512766}, 'score': 79.99, 'attributes': {'Status': 'M', 'Match_addr': '12 Berkley Avenue, West Derby, Liverpool, Merseyside, England, L12 4YS', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '12 Berkley Avenue', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L12 4YS', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.889222030778, 'ymin': 53.436972512766, 'xmax': -2.887222030778, 'ymax': 53.438972512766}}, {'address': '12 Berkley Street, Liverpool, Merseyside, England, L8 1XB', 'location': {'x': -2.967555281316, 'y': 53.395017489581}, 'score': 79.99, 'attributes': {'Status': 'M', 'Match_addr': '12 Berkley Street, Liverpool, Merseyside, England, L8 1XB', 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': '12 Berkley Street', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L8 1XB', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.968555281316, 'ymin': 53.394017489581, 'xmax': -2.966555281316, 'ymax': 53.396017489581}}, {'address': '12 Brewery Lane, Central Sefton, Melling, Liverpool, Merseyside, England, L31 1ET', 'location': {'x': -2.930774019533, 'y': 53.496724792522}, 'score': 77.06, 'attributes': {'Status': 'M', 'Match_addr': '12 Brewery Lane, Central Sefton, Melling, Liverpool, Merseyside, England, L31 1ET', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '12 Brewery Lane', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L31 1ET', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.931774019533, 'ymin': 53.495724792522, 'xmax': -2.929774019533, 'ymax': 53.497724792522}}, {'address': '12 Brewery Lane, Central Sefton, Formby, Liverpool, Merseyside, England, L37 7', 'location': {'x': -3.064385311981, 'y': 53.571793367549}, 'score': 77.06, 'attributes': {'Status': 'M', 'Match_addr': '12 Brewery Lane, Central Sefton, Formby, Liverpool, Merseyside, England, L37 7', 'Addr_type': 'StreetAddress', 'SubAddr': '', 'StAddr': '12 Brewery Lane', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L37 7', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -3.065385311981, 'ymin': 53.570793367549, 'xmax': -3.063385311981, 'ymax': 53.572793367549}}, {'address': '12 Garden Street, Woolton, Garston, Liverpool, Merseyside, England, L25 7RP', 'location': {'x': -2.869474898497, 'y': 53.374867217324}, 'score': 76.66, 'attributes': {'Status': 'M', 'Match_addr': '12 Garden Street, Woolton, Garston, Liverpool, Merseyside, England, L25 7RP', 'Addr_type': 'PointAddress', 'SubAddr': '', 'StAddr': '12 Garden Street', 'City': 'Liverpool', 'Subregion': 'Merseyside', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'L25 7RP', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -2.870474898497, 'ymin': 53.373867217324, 'xmax': -2.868474898497, 'ymax': 53.375867217324}}, {'address': '12 Garden Lane, Liverpool, Merseyside, England, L9 9EB', 'location': {'x': -2.937626707822, 'y': 53.46937793371}, 'sc ...
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '1203, Geneva', 'location': {'x': 6.1163025, 'y': 46.2125325}, 'score': 71.87, 'attributes': {'Status': 'M', 'Match_addr': '1203, Geneva', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Geneva', 'Subregion': 'Geneva', 'Region': 'Geneva', 'RegionAbbr': 'GE', 'Postal': '1203', 'CntryName': 'Switzerland', 'CountryCode': 'CHE'}, 'extent': {'xmin': 6.1063025, 'ymin': 46.2025325, 'xmax': 6.1263025, 'ymax': 46.2225325}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '10022, New York, New York', 'location': {'x': -73.968514, 'y': 40.758892}, 'score': 84, 'attributes': {'Status': 'M', 'Match_addr': '10022, New York, New York', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'New York', 'Subregion': 'New York County', 'Region': 'New York', 'RegionAbbr': 'NY', 'Postal': '10022', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -73.976514, 'ymin': 40.750892, 'xmax': -73.960514, 'ymax': 40.766892}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': []}
# Unexpected error for 90: list index out of range
# Error type: <class 'IndexError'>
# Arguments: ('list index out of range',)
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': '94019, Half Moon Bay, California', 'location': {'x': -122.4362243, 'y': 37.4673238}, 'score': 77, 'attributes': {'Status': 'M', 'Match_addr': '94019, Half Moon Bay, California', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Half Moon Bay', 'Subregion': 'San Mateo County', 'Region': 'California', 'RegionAbbr': 'CA', 'Postal': '94019', 'CntryName': 'United States', 'CountryCode': 'USA'}, 'extent': {'xmin': -122.5612243, 'ymin': 37.3423238, 'xmax': -122.3112243, 'ymax': 37.5923238}}]}
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'candidates': [{'address': 'PO31 7PJ, Cowes, England', 'location': {'x': -1.295548864312, 'y': 50.752588683158}, 'score': 86.5, 'attributes': {'Status': 'M', 'Match_addr': 'PO31 7PJ, Cowes, England', 'Addr_type': 'PostalExt', 'SubAddr': '', 'StAddr': '', 'City': 'Cowes', 'Subregion': 'Isle of Wight', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'PO31 7PJ', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -1.296548864312, 'ymin': 50.751588683158, 'xmax': -1.294548864312, 'ymax': 50.753588683158}}, {'address': 'PO31 8, Cowes, England', 'location': {'x': -1.313551, 'y': 50.7429659}, 'score': 82.3, 'attributes': {'Status': 'M', 'Match_addr': 'PO31 8, Cowes, England', 'Addr_type': 'Postal', 'SubAddr': '', 'StAddr': '', 'City': 'Cowes', 'Subregion': 'Isle of Wight', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'PO31 8', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -1.348551, 'ymin': 50.7079659, 'xmax': -1.278551, 'ymax': 50.7779659}}, {'address': 'Garden', 'location': {'x': -1.2980119, 'y': 50.7636124}, 'score': 78.67, 'attributes': {'Status': 'M', 'Match_addr': 'Garden', 'Addr_type': 'POI', 'SubAddr': '', 'StAddr': '48 High Street', 'City': 'Cowes', 'Subregion': 'Isle of Wight', 'Region': 'England', 'RegionAbbr': 'ENG', 'Postal': 'PO31 7RR', 'CntryName': 'United Kingdom', 'CountryCode': 'GBR'}, 'extent': {'xmin': -1.3030119, 'ymin': 50.7586124, 'xmax': -1.2930119, 'ymax': 50.7686124}}]}

# %%
# create dataframe
val_address_df = pd.DataFrame(val_addresses)
val_address_df
# Out:
#     CUSTOMER_ID         STD_ADDRESSLINE1 STD_ADDRESSLINE2       STD_CITY  \
# 0             1                     <NA>             <NA>     Manchester
# 1             2  1 Rue d'Alsace Lorraine             <NA>       Toulouse
# 2             3      Via Carlo Bianco 34             <NA>         Torino
# 3             4            201 Miller St             L 15         Sydney
# 4             5          54 Place Royale             <NA>         Nantes
# ..          ...                      ...              ...            ...
# 86           87        12 Barkeley Drive             <NA>      Liverpool
# 87           88                     <NA>             <NA>         Geneva
# 88           89                     <NA>             <NA>       New York
# 89           91                     <NA>             <NA>  Half Moon Bay
# 90           92                     <NA>             <NA>          Cowes
#
#           STD_REGION STD_REGIONCODE STD_POSTALCODE     STD_COUNTRY  \
# 0            England           <NA>           <NA>  United Kingdom
# 1          Occitanie           <NA>          31000          France
# 2           Piemonte           <NA>          10146          Italia
# 3    New South Wales            NSW           2060       Australia
# 4   Pays de la Loire            PDL          44000          France
# ..               ...            ...            ...             ...
# 86           England            ENG        L21 4LX  United Kingdom
# 87            Geneva             GE           1203     Switzerland
# 88          New York             NY          10022   United States
# 89        California             CA          94019   United States
# 90           England            ENG       PO31 7PJ  United Kingdom
#
#    STD_COUNTRY_CODE         ADDR_TYPE  \
# 0               GBR          Locality
# 1               FRA      PointAddress
# 2               ITA  StreetAddressExt
# 3               AUS        Subaddress
# 4               FRA  StreetAddressExt
# ..              ...               ...
# 86              GBR      PointAddress
# 87              CHE            Postal
# 88              USA            Postal
# 89              USA            Postal
# 90              GBR         PostalExt
#
#                                            MATCH_ADDR STATUS   SCORE
# 0             Manchester, Greater Manchester, England      T   71.50
# 1   1 Rue d'Alsace Lorraine, 31000, Toulouse, Haut...      M  100.00
# 2                  Via Carlo Bianco 34, 10146, Torino      M   93.22
# 3   201 Miller St, L 15, North Sydney, Sydney, New...      M  100.00
# 4   54 Place Royale, 44000, Nantes, Loire-Atlantiq...      M   96.30
# ..                                                ...    ...     ...
# 86  12 Barkeley Drive, Seaforth, Liverpool, Mersey...      M   80.14
# 87                                       1203, Geneva      M   71.87
# 88                          10022, New York, New York      M   84.00
# 89                   94019, Half Moon Bay, California      M   77.00
# 90                           PO31 7PJ, Cowes, England      M   86.50
#
# [91 rows x 13 columns]

# %%
# save output
val_address_df.to_csv('Output/val_address.csv', index=False, encoding='latin1')

# %%
# check address with error
address_df[address_df.CUSTOMER_ID == 90]
# Out:
#     CUSTOMER_ID     ADDRESSLINE1 ADDRESSLINE2  CITY STATE POSTALCODE COUNTRY  \
# 89           90  Berguvsvgen  8         None  Lule  None   S-958 22  Sweden
#
#    COUNTRY_CODE
# 89          SWE

# %% [markdown]
# ## Create Relational Tables
# ---

# %% [markdown]
# ### Customer Table
